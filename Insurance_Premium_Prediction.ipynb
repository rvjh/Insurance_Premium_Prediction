# %% [markdown]
# ## Importing Libraries

# %%
import pandas as pd
from pandas_profiling import ProfileReport
import matplotlib.pyplot as plt
import numpy as np
import pickle
import seaborn as sns

# %%
df = pd.read_csv('insurance.csv')
df.head()
# Out:
#    age     sex   bmi  children smoker     region  expenses
# 0   19  female  27.9         0    yes  southwest  16884.92
# 1   18    male  33.8         1     no  southeast   1725.55
# 2   28    male  33.0         3     no  southeast   4449.46
# 3   33    male  22.7         0     no  northwest  21984.47
# 4   32    male  28.9         0     no  northwest   3866.86

# %%
df.shape
# Out:
# (1338, 7)

# %%
df.describe().T
# Out:
#            count          mean           std      min        25%      50%  \
# age       1338.0     39.207025     14.049960    18.00    27.0000    39.00
# bmi       1338.0     30.665471      6.098382    16.00    26.3000    30.40
# children  1338.0      1.094918      1.205493     0.00     0.0000     1.00
# expenses  1338.0  13270.422414  12110.011240  1121.87  4740.2875  9382.03
#
#                 75%       max
# age          51.000     64.00
# bmi          34.700     53.10
# children      2.000      5.00
# expenses  16639.915  63770.43

# %%
df.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# expenses    0
# dtype: int64

# %%
df.dtypes
# Out:
# age           int64
# sex          object
# bmi         float64
# children      int64
# smoker       object
# region       object
# expenses    float64
# dtype: object

# %% [markdown]
# ## EDA

# %%
# %matplotlib inline
sns.pairplot(data=df,hue='expenses')
# Out:
# C:\Users\rohan\Anaconda3\lib\site-packages\seaborn\distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\rohan\Anaconda3\lib\site-packages\seaborn\distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\rohan\Anaconda3\lib\site-packages\seaborn\distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\rohan\Anaconda3\lib\site-packages\seaborn\distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\rohan\Anaconda3\lib\site-packages\seaborn\distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# ...

# %%
df.columns
# Out:
# Index(['age', 'sex', 'bmi', 'children', 'smoker', 'region', 'expenses'], dtype='object')

# %%
for i in df.columns:
    if df[i].dtype == 'object':
        print(f'Column {i} has data type {type(i)}')
# Out:
# Column sex has data type <class 'str'>
# Column smoker has data type <class 'str'>
# Column region has data type <class 'str'>

# %%
df['sex'].unique()
# Out:
# array(['female', 'male'], dtype=object)

# %%
df['smoker'].unique()
# Out:
# array(['yes', 'no'], dtype=object)

# %%
df['region'].unique()
# Out:
# array(['southwest', 'southeast', 'northwest', 'northeast'], dtype=object)

# %% [markdown]
# #### Creating columns based on the categorical  columns

# %%
categorical_columns = ['sex','smoker','region']
df = pd.get_dummies(data = df,
                    columns = categorical_columns,
                    drop_first = True)

df.head()
# Out:
#    age   bmi  children  expenses  sex_male  smoker_yes  region_northwest  \
# 0   19  27.9         0  16884.92         0           1                 0
# 1   18  33.8         1   1725.55         1           0                 0
# 2   28  33.0         3   4449.46         1           0                 0
# 3   33  22.7         0  21984.47         1           0                 1
# 4   32  28.9         0   3866.86         1           0                 1
#
#    region_southeast  region_southwest
# 0                 0                 1
# 1                 1                 0
# 2                 1                 0
# 3                 0                 0
# 4                 0                 0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   age               1338 non-null   int64
#  1   bmi               1338 non-null   float64
#  2   children          1338 non-null   int64
#  3   expenses          1338 non-null   float64
#  4   sex_male          1338 non-null   uint8
#  5   smoker_yes        1338 non-null   uint8
#  6   region_northwest  1338 non-null   uint8
#  7   region_southeast  1338 non-null   uint8
#  8   region_southwest  1338 non-null   uint8
# dtypes: float64(2), int64(2), uint8(5)
# memory usage: 48.5 KB

# %%
from sklearn.preprocessing import StandardScaler

sc = StandardScaler()

# %%
X = df.drop(columns=['expenses'])
y = df['expenses']

# %%
X
# Out:
#       age   bmi  children  sex_male  smoker_yes  region_northwest  \
# 0      19  27.9         0         0           1                 0
# 1      18  33.8         1         1           0                 0
# 2      28  33.0         3         1           0                 0
# 3      33  22.7         0         1           0                 1
# 4      32  28.9         0         1           0                 1
# ...   ...   ...       ...       ...         ...               ...
# 1333   50  31.0         3         1           0                 1
# 1334   18  31.9         0         0           0                 0
# 1335   18  36.9         0         0           0                 0
# 1336   21  25.8         0         0           0                 0
# 1337   61  29.1         0         0           1                 1
#
#       region_southeast  region_southwest
# 0                    0                 1
# 1                    1                 0
# 2                    1                 0
# ...

# %%
y
# Out:
# 0       16884.92
# 1        1725.55
# 2        4449.46
# 3       21984.47
# 4        3866.86
#           ...
# 1333    10600.55
# 1334     2205.98
# 1335     1629.83
# 1336     2007.95
# 1337    29141.36
# Name: expenses, Length: 1338, dtype: float64

# %% [markdown]
# #### Transforming the data

# %%
X[['age','bmi']] = sc.fit_transform(X[['age','bmi']])

# %%
X
# Out:
#            age       bmi  children  sex_male  smoker_yes  region_northwest  \
# 0    -1.438764 -0.453646         0         0           1                 0
# 1    -1.509965  0.514186         1         1           0                 0
# 2    -0.797954  0.382954         3         1           0                 0
# 3    -0.441948 -1.306650         0         1           0                 1
# 4    -0.513149 -0.289606         0         1           0                 1
# ...        ...       ...       ...       ...         ...               ...
# 1333  0.768473  0.054876         3         1           0                 1
# 1334 -1.509965  0.202511         0         0           0                 0
# 1335 -1.509965  1.022707         0         0           0                 0
# 1336 -1.296362 -0.798128         0         0           0                 0
# 1337  1.551686 -0.256799         0         0           1                 1
#
#       region_southeast  region_southwest
# ...

# %%
ProfileReport(X)
# Out:
# ...
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated with the `pandas-profiling` Python package&quot;&gt;&lt;meta name=author content=&quot;Simon Brugman and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;Pandas Profiling v3.1.0&quot;&gt;&lt;meta name=url content=https://github.com/pandas-profiling/pandas-profiling&gt;&lt;meta name=date content=&quot;2021-10-20 19:01:39.080070&quot;&gt;&lt;title&gt;Pandas Profiling Report&lt;/title&gt;&lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/master/LICENSE)
# ...

# %%
sns.pairplot(X,kind='scatter')

# %% [markdown]
# #### Checking the multicolinearity

# %%
import statsmodels.api as sm
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
# For each X, calculate VIF and save in dataframe
vif = pd.DataFrame()
vif["VIF Factor"] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
vif["features"] = X.columns

# %%
vif
# Out:
#    VIF Factor          features
# 0    1.016641               age
# 1    1.089566               bmi
# 2    1.617262          children
# 3    1.727619          sex_male
# 4    1.234919        smoker_yes
# 5    1.340547  region_northwest
# 6    1.461749  region_southeast
# 7    1.332922  region_southwest

# %%
import seaborn as sns
print(X.corr())
  
# plotting correlation heatmap 
dataplot = sns.heatmap(X.corr(), cmap="YlGnBu", annot=True)
  
# displaying heatmap
plt.show()
# Out:
#                        age       bmi  children  sex_male  smoker_yes  \
# age               1.000000  0.109341  0.042469 -0.020856   -0.025019
# bmi               0.109341  1.000000  0.012645  0.046380    0.003968
# children          0.042469  0.012645  1.000000  0.017163    0.007673
# sex_male         -0.020856  0.046380  0.017163  1.000000    0.076185
# smoker_yes       -0.025019  0.003968  0.007673  0.076185    1.000000
# region_northwest -0.000407 -0.135992  0.024806 -0.011156   -0.036945
# region_southeast -0.011642  0.270144 -0.023066  0.017117    0.068498
# region_southwest  0.010016 -0.006398  0.021914 -0.004184   -0.036945
#
#                   region_northwest  region_southeast  region_southwest
# age                      -0.000407         -0.011642          0.010016
# bmi                      -0.135992          0.270144         -0.006398
# children                  0.024806         -0.023066          0.021914
# ...

# %% [markdown]
# #### Train-test-split of dataset

# %%
# 20% data as validation set
from sklearn.model_selection import train_test_split

X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=22)

# %%
print("shape of X_train : ",X_train.shape)
print("shape of X_test : ",X_test.shape)
print("shape of y_train : ",y_train.shape)
print("shape of y_test : ",y_test.shape)
# Out:
# shape of X_train :  (1070, 8)
# shape of X_test :  (268, 8)
# shape of y_train :  (1070,)
# shape of y_test :  (268,)

# %%
# !pip install xgboost

# %% [markdown]
# #### importing different Regression libraries

# %%
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge,Lasso
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.svm import SVR
from xgboost import XGBRegressor
from sklearn.linear_model import RANSACRegressor
from sklearn.metrics import r2_score, mean_squared_error
from sklearn import metrics

# %%
## Defining different Regression algorithms  and names
algos = [LinearRegression(),
         Ridge(),
         Lasso(),
         DecisionTreeRegressor(),
         RandomForestRegressor(),
         KNeighborsRegressor(),
         SVR(),
         XGBRegressor(),
         RANSACRegressor()]

names = ['Linear Regression',
         'Ridge Regression',
         'Lasso Regression',
         'Decision Tree Regressor',
         'Random Forest Regressor',
         'KNeighbour Regressor',
         'Support Vector Regressor',
         'XGB Regressor',
         'Ransac Regressor']

## r2 score, adjusted_r2, Mean Square Log Error list to store the error values  
r2_square_err=[]
ms_err = []

# %%
for name in algos:
    model = name
    model.fit(X_train,y_train)
    y_pred=model.predict(X_test)
    r2 = metrics.r2_score(y_pred,y_test)
    ## just to simplify the meansquareerror value dividing by 10^8
    MSE = metrics.mean_squared_error(y_pred,y_test)/100000000
    r2_square_err.append(r2)
    ms_err.append(MSE)

# %%
len(names)
# Out:
# 9

# %%
len(r2_square_err)
# Out:
# 9

# %%
len(ms_err)
# Out:
# 9

# %%
evaluation = pd.DataFrame({'Model':names,
                          'R2_Error':r2_square_err,
                          'Mean Square Error': ms_err})

evaluation
# Out:
#                       Model      R2_Error  Mean Square Error
# 0         Linear Regression      0.660877           0.357041
# 1          Ridge Regression      0.657045           0.357646
# 2          Lasso Regression      0.660619           0.357090
# 3   Decision Tree Regressor      0.609039           0.614031
# 4   Random Forest Regressor      0.788312           0.272391
# 5      KNeighbour Regressor      0.396421           0.450157
# 6  Support Vector Regressor -66639.571448           1.644322
# 7             XGB Regressor      0.769553           0.315513
# 8          Ransac Regressor      0.741259           0.489053

# %% [markdown]
# #### As we can see XGBRegressor gives best results

# %% [markdown]
# #### Finding out the best parameters

# %%
from sklearn.model_selection import GridSearchCV

# %%
xgb = XGBRegressor()

params = {
    'n_estimators': [100,200,300,400],
    'max_depth': [1,2,3,4,5,6],
    'eta': [0.1,0.01,0.001,0.0001]
}

# %%
cross_val = GridSearchCV(estimator=xgb,param_grid=params,verbose=2)
cross_val.fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 96 candidates, totalling 480 fits
# [CV] END .............eta=0.1, max_depth=1, n_estimators=100; total time=   0.0s
# [CV] END .............eta=0.1, max_depth=1, n_estimators=100; total time=   0.0s
# [CV] END .............eta=0.1, max_depth=1, n_estimators=100; total time=   0.0s
# [CV] END .............eta=0.1, max_depth=1, n_estimators=100; total time=   0.0s
# [CV] END .............eta=0.1, max_depth=1, n_estimators=100; total time=   0.0s
# [CV] END .............eta=0.1, max_depth=1, n_estimators=200; total time=   0.1s
# [CV] END .............eta=0.1, max_depth=1, n_estimators=200; total time=   0.1s
# [CV] END .............eta=0.1, max_depth=1, n_estimators=200; total time=   0.1s
# [CV] END .............eta=0.1, max_depth=1, n_estimators=200; total time=   0.1s
# [CV] END .............eta=0.1, max_depth=1, n_estimators=200; total time=   0.1s
# [CV] END .............eta=0.1, max_depth=1, n_estimators=300; total time=   0.2s
# ...

# %%
cross_val.best_params_
# Out:
# {'eta': 0.01, 'max_depth': 3, 'n_estimators': 400}

# %%
model = XGBRegressor(n_estimators=400, max_depth=3 ,eta=0.01 )
model.fit(X_train,y_train)
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, enable_categorical=False,
#              eta=0.01, gamma=0, gpu_id=-1, importance_type=None,
#              interaction_constraints='', learning_rate=0.00999999978,
#              max_delta_step=0, max_depth=3, min_child_weight=1, missing=nan,
#              monotone_constraints='()', n_estimators=400, n_jobs=4,
#              num_parallel_tree=1, predictor='auto', random_state=0, reg_alpha=0,
#              reg_lambda=1, scale_pos_weight=1, subsample=1, tree_method='exact',
#              validate_parameters=1, verbosity=None)

# %%
y_pred = model.predict(X_test)
y_pred
# Out:
# array([15859.438 , 13816.415 ,  4989.1685, 12864.946 ,  4439.139 ,
#        15403.931 , 14800.424 , 40467.668 , 39800.03  ,  8908.241 ,
#         6009.664 , 17996.29  , 14489.189 , 11961.688 ,  6626.8994,
#        12437.617 ,  4468.8057,  8329.702 ,  6173.8657,  7404.454 ,
#        15403.931 ,  3058.9976, 12452.856 , 14470.311 , 12449.85  ,
#        26256.799 , 20779.049 , 12449.85  , 15096.734 ,  6264.6533,
#        10187.94  ,  9624.066 ,  8573.642 ,  6321.652 ,  8353.794 ,
#        21209.658 ,  2986.6826, 22343.12  ,  4547.5605, 23423.766 ,
#         6662.4204, 12484.387 , 10012.81  , 13436.143 , 14166.766 ,
#         5930.909 , 10315.188 ,  6365.869 , 44420.49  ,  7975.5596,
#         4523.7397,  4426.53  , 43264.58  ,  5589.723 ,  4260.661 ,
#         7078.449 , 44207.105 , 38812.094 ,  4543.631 , 12449.85  ,
#        42263.18  ,  2818.5078, 13952.839 ,  4347.775 ,  6009.664 ,
#        17223.613 ,  5724.0977,  7703.059 ,  4426.53  , 10843.773 ,
# ...

# %%
y_test
# Out:
# 1231    20167.34
# 768     14319.03
# 847      2438.06
# 510     11763.00
# 363      2597.78
#           ...
# 882      2585.85
# 1039    22493.66
# 874      8891.14
# 757     23065.42
# 701      9541.70
# Name: expenses, Length: 268, dtype: float64

# %%
print("Score on training set : ", model.score(X_train,y_train))
print("Score on testing set : ",model.score(X_test, y_test))
# Out:
# Score on training set :  0.8821636949404107
# Score on testing set :  0.8431221038216969

# %%
X_test
# Out:
#            age       bmi  children  sex_male  smoker_yes  region_northwest  \
# 1231 -1.367563 -1.454285         0         0           1                 0
# 768   1.765289  1.482017         0         0           0                 0
# 847  -1.153959  3.237237         1         1           0                 0
# 510   1.195680  0.235319         1         1           0                 0
# 363  -1.296362 -0.699705         1         0           0                 0
# ...        ...       ...       ...       ...         ...               ...
# 882  -1.296362 -1.405073         0         0           0                 0
# 1039 -1.438764 -0.552069         2         1           0                 1
# 874   0.341265 -1.437881         3         1           0                 0
# 757   0.554869 -0.470050         0         0           1                 0
# 701   0.768473  2.302213         0         0           0                 0
#
#       region_southeast  region_southwest
# ...

# %% [markdown]
# #### Saving the model

# %%
file_name = "insurance_predictor_xgb.sav"

# %%
pickle.dump(model, open(file_name,'wb'))
print("Model saved successfilly in the directory")
# Out:
# Model saved successfilly in the directory

# %%
## Load the model

load_mod = pickle.load(open(file_name,'rb'))

# %%
load_mod.predict([[10,15,0,3,1,1,1,1]])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-114-7f8a0191754f> in <module>
# ----> 1 load_mod.predict([[10,15,0,3,1,1,1,1]])
#
# ~\Anaconda3\lib\site-packages\xgboost\sklearn.py in predict(self, X, output_margin, ntree_limit, validate_features, base_margin, iteration_range)
#     901             enable_categorical=self.enable_categorical
#     902         )
# --> 903         return self.get_booster().predict(
#     904             data=test,
#     905             iteration_range=iteration_range,
#
# ~\Anaconda3\lib\site-packages\xgboost\core.py in predict(self, data, output_margin, ntree_limit, pred_leaf, pred_contribs, approx_contribs, pred_interactions, validate_features, training, iteration_range, strict_shape)
#    1885             raise TypeError('Expecting data to be a DMatrix object, got: ', type(data))
#    1886         if validate_features:
# ...
